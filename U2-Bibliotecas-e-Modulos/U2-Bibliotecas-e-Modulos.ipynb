# %%
# Importando biblioteca para gerar gráficos
import matplotlib.pyplot as plt

# Classe Livro
class Livro:
    def __init__(self, titulo, autor, genero, quantidade):
        self.titulo = titulo
        self.autor = autor
        self.genero = genero
        self.quantidade = quantidade

# Lista para armazenar os livros
livros = []

# Função para cadastrar livros
def cadastrar_livro():
    titulo = input("Digite o título do livro: ")
    autor = input("Digite o autor do livro: ")
    genero = input("Digite o gênero do livro: ")
    quantidade = int(input("Digite a quantidade disponível: "))

    livro = Livro(titulo, autor, genero, quantidade)
    livros.append(livro)

    print("Livro cadastrado com sucesso!\n")

# Função para listar livros
def listar_livros():
    print("\n===== LISTA DE LIVROS =====")

    for livro in livros:
        print(f"Título: {livro.titulo}")
        print(f"Autor: {livro.autor}")
        print(f"Gênero: {livro.genero}")
        print(f"Quantidade: {livro.quantidade}")
        print("---------------------------")

# Função para buscar livro pelo título
def buscar_livro():
    busca = input("Digite o título do livro para buscar: ")

    for livro in livros:
        if livro.titulo.lower() == busca.lower():
            print("\nLivro encontrado!")
            print(f"Título: {livro.titulo}")
            print(f"Autor: {livro.autor}")
            print(f"Gênero: {livro.genero}")
            print(f"Quantidade: {livro.quantidade}")
            return

    print("Livro não encontrado.")

# Função para gerar gráfico
def gerar_grafico():
    generos = {}

    for livro in livros:
        if livro.genero in generos:
            generos[livro.genero] += livro.quantidade
        else:
            generos[livro.genero] = livro.quantidade

    plt.bar(generos.keys(), generos.values())
    plt.title("Quantidade de Livros por Gênero")
    plt.xlabel("Gênero")
    plt.ylabel("Quantidade")
    plt.show()

# Programa principal
quantidade_livros = int(input("Quantos livros deseja cadastrar? "))

for i in range(quantidade_livros):
    cadastrar_livro()

listar_livros()
buscar_livro()
gerar_grafico()
# Out:
# Quantos livros deseja cadastrar? 3
# Digite o título do livro: A culpa das Estrelas
# Digite o autor do livro: Jonh Green
# Digite o gênero do livro: Romance
# Digite a quantidade disponível: 21
# Livro cadastrado com sucesso!
#
# Digite o título do livro: Assim que Começa
# Digite o autor do livro: Colleen Hoover
# Digite o gênero do livro: Romance
# Digite a quantidade disponível: 35
# Livro cadastrado com sucesso!
#
# Digite o título do livro: Assim que Acaba
# Digite o autor do livro: Colleen Hoover
# Digite o gênero do livro: Romance
# Digite a quantidade disponível: 72
# Livro cadastrado com sucesso!
#
#
# ===== LISTA DE LIVROS =====
# Título: A culpa das Estrelas
# Autor: Jonh Green
# Gênero: Romance
# Quantidade: 21
# ---------------------------
# Título: Assim que Começa
# Autor: Colleen Hoover
# Gênero: Romance
# Quantidade: 35
# ---------------------------
# Título: Assim que Acaba
# Autor: Colleen Hoover
# Gênero: Romance
# Quantidade: 72
# ---------------------------
# Digite o título do livro para buscar: Assim que Acaba
#
# Livro encontrado!
# Título: Assim que Acaba
# Autor: Colleen Hoover
# Gênero: Romance
# Quantidade: 72
